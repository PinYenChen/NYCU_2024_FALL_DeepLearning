# %% [markdown]
# # Just an example.You can alter sample code anywhere.

# %% [markdown]
# ## Mount your google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# You need to modify this part to the directory where your code is located
# %cd "/content/drive/MyDrive/DL_Lab1/"
# Out:
# /content/drive/MyDrive/DL_Lab1

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import pandas as pd

# %%
#Fix the random seed
np.random.seed(0)

# %% [markdown]
# ## Load the data and label

# %%
train_load = np.loadtxt('./data/kmnist-train.csv',delimiter=',',dtype="int")
train_data=train_load[:,1:]
train_label=train_load[:,0]
print("shape of train_data: {}".format(train_data.shape))
print("shape of train_label: {}".format(train_label.shape))
# Out:
# shape of train_data: (60000, 784)
# shape of train_label: (60000,)

# %% [markdown]
# ## Show the training data

# %%
# uncomment if you want to show the training data
#plt.figure(figsize=(20, 20))
#for index in range(10):
#    image = train_data[index+20000].reshape(28,28)
#    plt.subplot(2, 5, index+1)
#    plt.imshow(image)
#plt.show()

# %%
train_image_num = train_data.shape[0]
train_data = train_data.astype('float32')

print("train_image_num  is : {}".format(train_image_num))
# Out:
# train_image_num  is : 60000

# %% [markdown]
# ## Change numpy array to pytorch tensor

# %%
train_data_tensor = torch.from_numpy(train_data)
train_label_tensor = torch.from_numpy(train_label)

# %% [markdown]
# ## Validation image number

# %%
val_image_num=10000

# %% [markdown]
# ## Convert labels to one hot vector

# %%
label_temp = np.zeros((train_image_num, 10), dtype = np.float32)
for i in range(train_image_num):
    label_temp[i][train_label[i]] = 1
train_label_onehot = np.copy(label_temp)
train_label_onehot_tensor = torch.from_numpy(train_label_onehot)
print("One-hot training labels shape:",train_label_onehot.shape)
# Out:
# One-hot training labels shape: (60000, 10)

# %% [markdown]
# ## Hyperparameters

# %%
EPOCH = 50
Batch_size = 50 # 10000 should be divisible by batch_size
Learning_rate = 0.001

# %% [markdown]
# ## Define the models with pytorch

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # Define the network layers
        self.fc1 = nn.Linear(28*28, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 10)

    def forward(self, x):
        # Flatten the input tensor
        x = x.view(-1, 28*28)

        # Pass the input through the network layers
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)

        return x  # 返回 logits

# Instantiate the model
net = Net()

# %% [markdown]
# ## Criterion and Optimizer

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(net.parameters(), lr=0.001)

# %% [markdown]
# ## Training

# %%
train_batch_num = (train_image_num - val_image_num )//Batch_size
val_batch_num = (val_image_num)//Batch_size

for epoch in range(1, EPOCH+1):
    train_hit = 0
    val_hit = 0
    total_train_loss = 0.0
    total_val_loss = 0.0
    for it in range(train_batch_num):
        optimizer.zero_grad()
        outputs = net(train_data_tensor[it*Batch_size:(it+1)*Batch_size])
        _, pred_index = torch.max(outputs, 1)
        train_hit += (pred_index == train_label_tensor[it*Batch_size:(it+1)*Batch_size]).sum().item()
        loss = criterion(outputs, train_label_onehot_tensor[it*Batch_size:(it+1)*Batch_size])
        loss.backward()
        optimizer.step()
        total_train_loss += loss.item()

    with torch.no_grad():
        for titt in range(val_batch_num):
            tit=train_batch_num+titt
            outputs = net(train_data_tensor[tit*Batch_size:(tit+1)*Batch_size])
            _, pred_index = torch.max(outputs, 1)
            val_hit += (pred_index == train_label_tensor[tit*Batch_size:(tit+1)*Batch_size]).sum().item()
            loss = criterion(outputs, train_label_onehot_tensor[tit*Batch_size:(tit+1)*Batch_size])
            total_val_loss += loss.item()

    print('Task2  | Epoch:%3d'%epoch, ' |Train Loss:%8.4f'%(total_train_loss/train_batch_num), ' |Train Acc:%3.4f'%(train_hit/(train_image_num-val_image_num)*100.0)
          , ' |Val Loss:%8.4f'%(total_val_loss/val_batch_num), ' |Val Acc:%3.4f'%(val_hit/val_image_num*100.0))
# Out:
# Task2  | Epoch:  1  |Train Loss:  0.4601  |Train Acc:86.3300  |Val Loss:  0.2556  |Val Acc:92.3300
# Task2  | Epoch:  2  |Train Loss:  0.2311  |Train Acc:93.0640  |Val Loss:  0.2550  |Val Acc:92.5900
# Task2  | Epoch:  3  |Train Loss:  0.1699  |Train Acc:94.8320  |Val Loss:  0.2321  |Val Acc:93.3400
# Task2  | Epoch:  4  |Train Loss:  0.1403  |Train Acc:95.8000  |Val Loss:  0.2466  |Val Acc:93.5000
# Task2  | Epoch:  5  |Train Loss:  0.1301  |Train Acc:96.1560  |Val Loss:  0.2363  |Val Acc:94.3800
# Task2  | Epoch:  6  |Train Loss:  0.1105  |Train Acc:96.7540  |Val Loss:  0.2405  |Val Acc:94.2300
# Task2  | Epoch:  7  |Train Loss:  0.0997  |Train Acc:97.0720  |Val Loss:  0.2208  |Val Acc:95.1800
# Task2  | Epoch:  8  |Train Loss:  0.0908  |Train Acc:97.2700  |Val Loss:  0.2353  |Val Acc:94.7600
# Task2  | Epoch:  9  |Train Loss:  0.0854  |Train Acc:97.5580  |Val Loss:  0.2239  |Val Acc:95.2100
# Task2  | Epoch: 10  |Train Loss:  0.0765  |Train Acc:97.8420  |Val Loss:  0.2538  |Val Acc:94.4200
# Task2  | Epoch: 11  |Train Loss:  0.0745  |Train Acc:97.9120  |Val Loss:  0.2562  |Val Acc:94.7900
# Task2  | Epoch: 12  |Train Loss:  0.0699  |Train Acc:98.0860  |Val Loss:  0.2688  |Val Acc:94.9300
# Task2  | Epoch: 13  |Train Loss:  0.0660  |Train Acc:98.2460  |Val Loss:  0.2625  |Val Acc:95.1300
# Task2  | Epoch: 14  |Train Loss:  0.0623  |Train Acc:98.2940  |Val Loss:  0.2510  |Val Acc:95.4000
# Task2  | Epoch: 15  |Train Loss:  0.0544  |Train Acc:98.5120  |Val Loss:  0.2742  |Val Acc:95.4500
# Task2  | Epoch: 16  |Train Loss:  0.0591  |Train Acc:98.4140  |Val Loss:  0.3042  |Val Acc:95.2200
# Task2  | Epoch: 17  |Train Loss:  0.0565  |Train Acc:98.5000  |Val Loss:  0.3053  |Val Acc:95.2500
# Task2  | Epoch: 18  |Train Loss:  0.0497  |Train Acc:98.7700  |Val Loss:  0.3898  |Val Acc:94.5400
# Task2  | Epoch: 19  |Train Loss:  0.0558  |Train Acc:98.6720  |Val Loss:  0.3618  |Val Acc:94.4800
# Task2  | Epoch: 20  |Train Loss:  0.0502  |Train Acc:98.7600  |Val Loss:  0.3092  |Val Acc:95.4800
# Task2  | Epoch: 21  |Train Loss:  0.0468  |Train Acc:98.8480  |Val Loss:  0.3532  |Val Acc:95.3900
# Task2  | Epoch: 22  |Train Loss:  0.0411  |Train Acc:98.9200  |Val Loss:  0.3843  |Val Acc:94.7200
# Task2  | Epoch: 23  |Train Loss:  0.0465  |Train Acc:98.8940  |Val Loss:  0.3106  |Val Acc:95.5300
# Task2  | Epoch: 24  |Train Loss:  0.0466  |Train Acc:98.9040  |Val Loss:  0.3634  |Val Acc:95.1800
# Task2  | Epoch: 25  |Train Loss:  0.0496  |Train Acc:98.9100  |Val Loss:  0.3494  |Val Acc:95.2600
# Task2  | Epoch: 26  |Train Loss:  0.0393  |Train Acc:99.0500  |Val Loss:  0.3250  |Val Acc:95.2300
# Task2  | Epoch: 27  |Train Loss:  0.0461  |Train Acc:99.0220  |Val Loss:  0.3686  |Val Acc:95.3500
# Task2  | Epoch: 28  |Train Loss:  0.0462  |Train Acc:98.9860  |Val Loss:  0.3596  |Val Acc:95.1100
# Task2  | Epoch: 29  |Train Loss:  0.0426  |Train Acc:99.0720  |Val Loss:  0.3918  |Val Acc:95.2100
# Task2  | Epoch: 30  |Train Loss:  0.0341  |Train Acc:99.2120  |Val Loss:  0.3846  |Val Acc:95.6000
# Task2  | Epoch: 31  |Train Loss:  0.0348  |Train Acc:99.2380  |Val Loss:  0.4194  |Val Acc:95.3800
# Task2  | Epoch: 32  |Train Loss:  0.0394  |Train Acc:99.1640  |Val Loss:  0.3654  |Val Acc:95.5100
# Task2  | Epoch: 33  |Train Loss:  0.0425  |Train Acc:99.1220  |Val Loss:  0.3760  |Val Acc:95.8300
# Task2  | Epoch: 34  |Train Loss:  0.0336  |Train Acc:99.2660  |Val Loss:  0.3682  |Val Acc:95.8000
# Task2  | Epoch: 35  |Train Loss:  0.0388  |Train Acc:99.2280  |Val Loss:  0.4134  |Val Acc:95.5500
# Task2  | Epoch: 36  |Train Loss:  0.0369  |Train Acc:99.3300  |Val Loss:  0.3861  |Val Acc:95.7600
# Task2  | Epoch: 37  |Train Loss:  0.0331  |Train Acc:99.3060  |Val Loss:  0.4409  |Val Acc:95.5800
# Task2  | Epoch: 38  |Train Loss:  0.0342  |Train Acc:99.2980  |Val Loss:  0.4117  |Val Acc:95.6100
# Task2  | Epoch: 39  |Train Loss:  0.0346  |Train Acc:99.3400  |Val Loss:  0.3914  |Val Acc:95.7600
# Task2  | Epoch: 40  |Train Loss:  0.0295  |Train Acc:99.4100  |Val Loss:  0.4434  |Val Acc:95.5700
# Task2  | Epoch: 41  |Train Loss:  0.0353  |Train Acc:99.3560  |Val Loss:  0.4818  |Val Acc:95.2300
# Task2  | Epoch: 42  |Train Loss:  0.0306  |Train Acc:99.4720  |Val Loss:  0.5294  |Val Acc:95.2300
# Task2  | Epoch: 43  |Train Loss:  0.0440  |Train Acc:99.2740  |Val Loss:  0.5206  |Val Acc:95.8300
# Task2  | Epoch: 44  |Train Loss:  0.0350  |Train Acc:99.3780  |Val Loss:  0.3967  |Val Acc:95.7800
# Task2  | Epoch: 45  |Train Loss:  0.0276  |Train Acc:99.4700  |Val Loss:  0.4444  |Val Acc:95.5200
# Task2  | Epoch: 46  |Train Loss:  0.0353  |Train Acc:99.3520  |Val Loss:  0.4657  |Val Acc:95.2900
# Task2  | Epoch: 47  |Train Loss:  0.0294  |Train Acc:99.4320  |Val Loss:  0.4642  |Val Acc:95.6700
# Task2  | Epoch: 48  |Train Loss:  0.0295  |Train Acc:99.4320  |Val Loss:  0.5104  |Val Acc:95.7100
# Task2  | Epoch: 49  |Train Loss:  0.0284  |Train Acc:99.4980  |Val Loss:  0.4419  |Val Acc:95.8200
# Task2  | Epoch: 50  |Train Loss:  0.0361  |Train Acc:99.3540  |Val Loss:  0.4207  |Val Acc:95.5300
